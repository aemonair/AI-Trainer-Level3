# %%
LinearRegression
pipeline
(标准化
回归模型)

7 SMOTE
smote.fit_resample

8 pd.get_dummies()

9 pickle.dump() joblib.dump()

10 mean_squared_error(MSE)

11 mean_absolute_error

12 r2_score R^2

13 fit(X, y) predict(X) score(X, y)

Fitting
model.fit()
model.predict(X_test)
