# %%
import onnxruntime as ort
# 1
ort.InferenceSession()
# 2
input_info = ort_session.get_inputs() -> name ,shape,type
# 3
session.run(output_names, input_feed)

# PIL/ OpenCV
from PIL import Image
# 4
img = Image.open()
print (img)
# 5
image.convert('RGB') # RGB #L #RGBA
# 6
resized_img = image.resize((width, height))

#7
img_bgr = cv2.imread('.jpg') # return (width,height,channel) 
# 8
vc2.resize(src, (width, height))

# Numpy
# 9
arr = np.array(pil_image)

# 10
np.expand_dims() # 1, Height, Width, Channel axis=
 
 # 11
 np.argmax() # axis: int ,optional
 
 # 12
 np.argsort()
[::-1]

# Softmax
from scipy.special import softmax
# 13 概率分布
scipy.special.softmax()

# File
# 14
open()
# 15
.strip()
# 16
os.makedirs()
